# %% [markdown]
# Los datos que se incluyen en el fichero `datos_ventas_centros_comerciales.csv` representan casi 100.000 compra-ventas realizadas en un grupo de Centros Comerciales durantes los años 2021 y 2022.

# %% [markdown]
# # 1. ¿Cuál es el total de ingresos generados por todas las ventas registradas?
# Guarda el resultado en una variable llamada `total_ingresos`

# %%
import pandas as pd
pd.read_csv("datos_ventas_centros_comerciales.csv")
df["invoice_date"] = pd.to_datetime(df["invoice_date"], dayfirst=True)

# En este proyecto interpretaré "ventas" como "ingresos generados", tal como se utiliza en el contexto comercial del dataset.
df["total"] = df["price"] * df["quantity"]
total_ingresos = df["total"].sum()
print("Total de ingresos generados:",round(total_ingresos, 2))
# Out:
# Total de ingresos generados: 1490921515.71

# %% [markdown]
# # 2. ¿Cuál es el centro comercial que ha generado más ventas?
# Guarda el resultado en una variable llamada `centro_comercial_mas_ventas`

# %%
ventas_por_centro = df.groupby("shopping_mall")["total"].sum()
centro_comercial_mas_ventas = ventas_por_centro.idxmax()
print("Centro comercial con más ventas:", centro_comercial_mas_ventas)
# Out:
# Centro comercial con más ventas: Mall of Istanbul

# %% [markdown]
# # 3. ¿Cuál es la categoría de producto que ha generado mas ventas?
# Guarda el resultado en una variable llamada `categoria_mas_vendida`

# %%
ingresos_por_categoria = df.groupby("category")["total"].sum()
categoria_mas_vendida = ingresos_por_categoria.idxmax()
print("Categoría con más ventas:", categoria_mas_vendida)
# Out:
# Categoría con más ventas: Clothing

# %% [markdown]
# # 4. ¿Cuál es el producto más caro vendido?
# Guarda el resultado en una variable llamada `categoria_producto_mas_caro`

# %%
categoria_producto_mas_caro = df.loc[df["price"].idxmax(), "category"]
print("Categoría del producto más caro:", categoria_producto_mas_caro)
# Out:
# Categoría del producto más caro: Toys

# %% [markdown]
# # 5. ¿Cuál es la factura más antigua registrada en el dataset?
# Guarda el resultado en una variable llamada `factura_mas_antigua`

# %%
factura_mas_antigua = df.loc[df["invoice_date"].idxmin(), "invoice_no"]
print("Factura más antigua:", factura_mas_antigua)
# Out:
# Factura más antigua: I301161

# %% [markdown]
# # 6. ¿Cuál es la cantidad promedio de productos vendidos por transacción?
# Guarda el resultado en una variable llamada `cantidad_promedio_por_transaccion`

# %%
productos_por_factura = df.groupby("invoice_no")["quantity"].sum()
cantidad_promedio_por_transaccion = round(productos_por_factura.mean())
print("Cantidad promedio de productos por transacción:", cantidad_promedio_por_transaccion)
# Out:
# Cantidad promedio de productos por transacción: 3

# %% [markdown]
# # 7. ¿Cuál es el día con más ventas registradas?
# Guarda el resultado en una variable llamada `dia_con_mas_ventas`

# %%
ventas_por_dia = df.groupby(df["invoice_date"].dt.date)["total"].sum()
dia_con_mas_ventas = ventas_por_dia.idxmax().strftime("%d/%m/%Y")
print("Día con más ventas registradas:", dia_con_mas_ventas)
# Out:
# Día con más ventas registradas: 07/01/2022

# %% [markdown]
# # 8. ¿Cuál es el cliente que más ha gastado en total?
# Guarda el resultado en una variable llamada `cliente_que_mas_gasto`

# %%
gasto_por_cliente = df.groupby("customer_id")["total"].sum()
cliente_que_mas_gasto = gasto_por_cliente.idxmax()
print("Cliente que más gastó:", cliente_que_mas_gasto)
# Out:
# Cliente que más gastó: C307063

# %% [markdown]
# # 9. ¿Cuál es la factura con el precio total más alto?
# Guarda el resultado en una variable llamada `factura_max_valor`

# %%
total_por_factura = df.groupby("invoice_no")["total"].sum()
factura_max_valor = total_por_factura.idxmax()
print("Factura con mayor valor total:", factura_max_valor)
# Out:
# Factura con mayor valor total: I311640

# %% [markdown]
# # 10. ¿Cuál es la distribución porcentual de ventas por categoría de producto?
# Guarda el resultado en una variable llamada `distribucion_porcentual_ventas_por_categoria`. El tipo de `distribucion_porcentual_ventas_por_categoria` debe ser `pandas.core.series.Series` donde las etiquetas deben ser las categorias y los valores deben ser la distribucion porcentual de las ventas por categoría

# %%
distribucion_porcentual_ventas_por_categoria = (ingresos_por_categoria / ingresos_por_categoria.sum() * 100
).round(2).sort_values(ascending=False)
print("Distribución porcentual de ventas por categoría:\n")
print(distribucion_porcentual_ventas_por_categoria.to_string())
# Out:
# Distribución porcentual de ventas por categoría:
#
# category
# Clothing           34.50
# Cosmetics          15.22
# Food & Beverage    14.92
# Shoes              10.17
# Toys               10.16
# Technology          5.06
# Books               4.99
# Souvenir            4.97

# %% [markdown]
# # 11. ¿Cuál es el día de la semana con más ventas registradas en cada centro comercial?
# Guarda el resultado en una variable llamada `dia_semana_mas_ventas_por_centro`. El tipo de `dia_semana_mas_ventas_por_centro` debe ser `pandas.core.series.Series` donde las etiquetas deben ser el nombre de los centros comerciales y los valores deben ser el nombre del dia de la semana con mas ventas.

# %%
df["dia_semana"] = df["invoice_date"].dt.day_name()
ventas_centro_dia = df.groupby(["shopping_mall", "dia_semana"])["total"].sum()
dia_semana_mas_ventas_por_centro = (ventas_centro_dia.groupby(level=0).idxmax().apply(lambda x: x[1]))
print("Día de la semana con más ventas (ingresos) por centro comercial:\n")
print(dia_semana_mas_ventas_por_centro.to_string())
# Out:
# Día de la semana con más ventas (ingresos) por centro comercial:
#
# shopping_mall
# Cevahir AVM              Sunday
# Emaar Square Mall        Friday
# Forum Istanbul           Monday
# Istinye Park             Friday
# Kanyon                   Monday
# Mall of Istanbul        Tuesday
# Mall of Istanbul      Wednesday
# Metrocity               Tuesday
# Metropol AVM            Tuesday
# Viaport Outlet           Friday
# Zorlu Center           Thursday
